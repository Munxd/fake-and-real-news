# %%
import pandas as pd

df_fake = pd.read_csv('Fake.csv')
df_true = pd.read_csv('True.csv')

print(f"Gerçek haber sayısı: {len(df_true)}")
print(f"Sahte haber sayısı: {len(df_fake)}")
# Out:
# Gerçek haber sayısı: 21417
# Sahte haber sayısı: 23481
